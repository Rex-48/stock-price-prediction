# %% [markdown]
# # Stock Price Prediction

# %%
# importing required libraries

import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## @Downloading dataset

# %%
## downloading dataset in the Like a chad 

import kagglehub
import shutil
import os

dataset_handle = "dgawlik/nyse"

# Step 1: Summon the mighty Kaggle servers to drop the dataset into cache
download_path = kagglehub.dataset_download(dataset_handle)

print("Dataset downloaded to cache:", download_path)

destination = os.path.abspath("../data/nyse")
os.makedirs(destination, exist_ok=True)

# Copying files manually like it’s 2005 because kagglehub refuses to just save them there
for file in os.listdir(download_path):
    src = os.path.join(download_path, file)
    dst = os.path.join(destination, file)
    if os.path.isfile(src):
        shutil.copy2(src, dst)

print("Dataset copied to:", destination)

import pandas as pd

# Finally, the good stuff — data!
prices = pd.read_csv(os.path.join(destination, "prices.csv"))
print(prices.head())
# Out:
# Dataset downloaded to cache: /home/rohit/.cache/kagglehub/datasets/dgawlik/nyse/versions/3
# Dataset copied to: /home/rohit/Code/projects/machine_learning/stock-price-predictions/data/nyse
#                   date symbol        open       close         low        high  \
# 0  2016-01-05 00:00:00   WLTW  123.430000  125.839996  122.309998  126.250000
# 1  2016-01-06 00:00:00   WLTW  125.239998  119.980003  119.940002  125.540001
# 2  2016-01-07 00:00:00   WLTW  116.379997  114.949997  114.930000  119.739998
# 3  2016-01-08 00:00:00   WLTW  115.480003  116.620003  113.500000  117.440002
# 4  2016-01-11 00:00:00   WLTW  117.010002  114.970001  114.089996  117.330002
#
#       volume
# 0  2163600.0
# 1  2386400.0
# 2  2489500.0
# 3  2006300.0
# 4  1408600.0

# %%
# Importing dataset

data = pd.read_csv("../data/nyse/prices-split-adjusted.csv")
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#          date symbol        open       close         low        high  \
# 0  2016-01-05   WLTW  123.430000  125.839996  122.309998  126.250000
# 1  2016-01-06   WLTW  125.239998  119.980003  119.940002  125.540001
# 2  2016-01-07   WLTW  116.379997  114.949997  114.930000  119.739998
# 3  2016-01-08   WLTW  115.480003  116.620003  113.500000  117.440002
# 4  2016-01-11   WLTW  117.010002  114.970001  114.089996  117.330002
#
#       volume
# 0  2163600.0
# 1  2386400.0
# 2  2489500.0
# 3  2006300.0
# 4  1408600.0

# %% [markdown]
# ### Data_Info

# %%
df.describe()
# Out:
#                 open          close            low           high  \
# count  851264.000000  851264.000000  851264.000000  851264.000000
# mean       64.993618      65.011913      64.336541      65.639748
# std        75.203893      75.201216      74.459518      75.906861
# min         1.660000       1.590000       1.500000       1.810000
# 25%        31.270000      31.292776      30.940001      31.620001
# 50%        48.459999      48.480000      47.970001      48.959999
# 75%        75.120003      75.139999      74.400002      75.849998
# max      1584.439941    1578.130005    1549.939941    1600.930054
#
#              volume
# count  8.512640e+05
# mean   5.415113e+06
# std    1.249468e+07
# min    0.000000e+00
# 25%    1.221500e+06
# 50%    2.476250e+06
# 75%    5.222500e+06
# max    8.596434e+08

# %%
# showing column wise %ge of NaN values they contains 

for i in df.columns:
  print(i,"\t-\t", df[i].isna().mean()*100)
# Out:
# date 	-	 0.0
# symbol 	-	 0.0
# open 	-	 0.0
# close 	-	 0.0
# low 	-	 0.0
# high 	-	 0.0
# volume 	-	 0.0

# %%
df = df[df['symbol'] == 'AAP']  # Laser-focusing on one poor company's data

# Kick out the columns that can't do math before asking for correlations
cormap = df.select_dtypes(include='number').corr()

fig, ax = plt.subplots(figsize=(5, 5))
sns.heatmap(cormap, annot=True)
plt.show()

# %%
def get_corelated_col(cor_dat, threshold):
    # Only the drama queens above this threshold get invited
    feature = []
    value = []

    for i, index in enumerate(cor_dat.index):
        if abs(cor_dat[index]) > threshold:
            feature.append(index)
            value.append(cor_dat[index])

    # Making a nice little table for the popular columns
    df = pd.DataFrame(data=value, index=feature, columns=['corr value'])
    return df

# %%
top_corelated_values = get_corelated_col(cormap['close'], 0.60)
top_corelated_values
# Out:
#        corr value
# open     0.999382
# close    1.000000
# low      0.999615
# high     0.999737

# %% [markdown]
# > Looks like all colums except _volume_ are ***highly co-related***. Using them for predictions.

# %%
df = df[top_corelated_values.index]
df.head()
# Out:
#            open      close        low       high
# 253   40.700001  40.380001  40.360001  41.040001
# 720   40.299999  40.139999  39.720001  40.310001
# 1188  40.049999  40.490002  40.049999  40.779999
# 1656  39.549999  40.480000  39.549999  40.540001
# 2124  40.250000  40.639999  40.110001  40.820000

# %%
df.shape
# Out:
# (1762, 4)

# %%
sns.pairplot(df)
plt.tight_layout()

# %% [markdown]
# > Since other parameters have linear relationship with __close__, we are using some linear models fore prediction

# %%
X = df.drop(['close'], axis=1)
y = df['close']

# %% [markdown]
# > Since range of data in different columns veries significantly we need to scale the independent variable i.e. X. For this we will use Min-Max Scaling.

# %%
from sklearn.preprocessing import MinMaxScaler
import pandas as pd

scaler = MinMaxScaler()
# Forcing all columns to obey the 0-1 dictatorship
X = pd.DataFrame(scaler.fit_transform(X), columns=X.columns)
X.head()
# Out:
#        open       low      high
# 0  0.012001  0.012392  0.010256
# 1  0.009539  0.008387  0.005746
# 2  0.008000  0.010452  0.008649
# 3  0.004923  0.007323  0.007167
# 4  0.009231  0.010827  0.008897

# %%
from sklearn.model_selection import train_test_split

# Let's split the chaos into a training playground and a testing lab
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# To keep track of how well we pretend to predict
Acc = []

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# Summoning the almighty Linear Regression to try and predict the future
model_1 = LinearRegression()
model_1.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Asking Linear Regression to spill the future
y_pred_1 = model_1.predict(X_test)

# Comparing reality vs. the model's crystal ball
pred_df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred_1})
pred_df.head()
# Out:
#             Actual   Predicted
# 675111  173.660004  173.682489
# 675608  171.919998  172.593759
# 676105  172.000000  171.182789
# 676602  187.789993  187.980305
# 677099  187.029999  188.440838

# %%
from sklearn.metrics import r2_score

# How much does our crystal ball suck… I mean, predict?
score = r2_score(y_test, y_pred_1)
print(f"Accuracy score of the predictions: {score}")

# Stashing the glory (or shame) for later
Acc.append(score)
# Out:
# Accuracy score of the predictions: 0.9931342019332019

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 8))
plt.ylabel('Close Price', fontsize=16)

# Actual vs model's best guess
plt.plot(pred_df['Actual'], color='blue')
plt.plot(pred_df['Predicted'], color='orange')

plt.legend(['Actual Value', 'Predictions'])
plt.title("Actual vs Predicted Close Prices (Linear Regression trying its best)")
plt.show()

# %% [markdown]
# ## ANN

# %%
from keras.models import Sequential
from keras.layers import Dense

def regressor(inp_dim):
    # Summoning the mighty feedforward neural network to try predicting the unpredictable
    model = Sequential()
    
    model.add(Dense(20, input_dim=inp_dim, kernel_initializer='normal', activation='relu'))
    model.add(Dense(25, kernel_initializer='normal', activation='relu'))
    model.add(Dense(10, kernel_initializer='normal', activation='relu'))
    model.add(Dense(1, kernel_initializer='normal'))  # One output to rule them all
    
    model.compile(loss='mean_squared_error', optimizer='adam')
    
    return model
# Out:
# 2025-09-18 10:45:07.152782: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-09-18 10:45:07.153028: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-09-18 10:45:07.154983: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-09-18 10:45:07.172614: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-09-18 10:45:07.696093: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# the polishing the crystal ball 

model_2 = regressor(inp_dim=3)
model_2.fit(X_train, y_train, epochs=70, validation_split=0.2)
# Out:
# Epoch 1/70
# /home/rohit/miniconda3/envs/env/lib/python3.9/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2025-09-18 10:45:08.150961: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-09-18 10:45:08.157020: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6067.0879 - val_loss: 22080.7773
# Epoch 2/70
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6130.3340 - val_loss: 21977.5098
# Epoch 3/70
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5927.0747 - val_loss: 21518.4180
# Epoch 4/70
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5874.2632 - val_loss: 20045.6426
# Epoch 5/70
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5246.6030 - val_loss: 16556.8301
# Epoch 6/70
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3900.6797 - val_loss: 10691.7178
# Epoch 7/70
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2033.2345 - val_loss: 4267.2783
# Epoch 8/70
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 570.1174 - val_loss: 865.8122
# Epoch 9/70
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 55.1487 - val_loss: 265.3283
# Epoch 10/70
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 26.8509 - val_loss: 240.9285
# Epoch 11/70
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 26.9159 - val_loss: 235.9261
# Epoch 12/70
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 22.9551 - val_loss: 219.5194
# Epoch 13/70
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 21.8451 - val_loss: 198.1076
# Epoch 14/70
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 20.7752 - val_loss: 183.9246
# Epoch 15/70
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 19.2995 - val_loss: 170.9624
# Epoch 16/70
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 17.4016 - val_loss: 158.0853
# Epoch 17/70
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 16.0867 - val_loss: 140.2940
# Epoch 18/70
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 13.6186 - val_loss: 126.2887
# Epoch 19/70
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 12.5800 - val_loss: 113.8925
# Epoch 20/70
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 11.5007 - val_loss: 103.0613
# Epoch 21/70
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 10.2036 - val_loss: 91.2830
# Epoch 22/70
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.3833 - val_loss: 83.3307
# Epoch 23/70
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.3359 - val_loss: 71.9988
# Epoch 24/70
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.2584 - val_loss: 62.9958
# Epoch 25/70
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.6479 - val_loss: 58.0898
# Epoch 26/70
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.1100 - val_loss: 50.0193
# Epoch 27/70
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.2764 - val_loss: 42.6072
# Epoch 28/70
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.3484 - val_loss: 38.3898
# Epoch 29/70
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.3274 - val_loss: 32.9511
# Epoch 30/70
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.7800 - val_loss: 29.2388
# Epoch 31/70
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.1069 - val_loss: 24.7500
# Epoch 32/70
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6459 - val_loss: 22.3554
# Epoch 33/70
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.3514 - val_loss: 18.5473
# Epoch 34/70
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.0618 - val_loss: 16.7826
# Epoch 35/70
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.7358 - val_loss: 13.0380
# Epoch 36/70
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5016 - val_loss: 11.8253
# Epoch 37/70
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4650 - val_loss: 10.1290
# Epoch 38/70
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2490 - val_loss: 8.5845
# Epoch 39/70
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0277 - val_loss: 7.4324
# Epoch 40/70
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.9109 - val_loss: 6.8215
# Epoch 41/70
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.9254 - val_loss: 5.3747
# Epoch 42/70
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7880 - val_loss: 4.8715
# Epoch 43/70
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7299 - val_loss: 4.3726
# Epoch 44/70
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6619 - val_loss: 3.9776
# Epoch 45/70
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5754 - val_loss: 3.4553
# Epoch 46/70
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5763 - val_loss: 3.0816
# Epoch 47/70
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5960 - val_loss: 3.0599
# Epoch 48/70
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4983 - val_loss: 2.4849
# Epoch 49/70
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5336 - val_loss: 2.5884
# Epoch 50/70
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5468 - val_loss: 2.3133
# Epoch 51/70
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5773 - val_loss: 2.3026
# Epoch 52/70
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4560 - val_loss: 2.1188
# Epoch 53/70
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4801 - val_loss: 2.0588
# Epoch 54/70
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4879 - val_loss: 2.0648
# Epoch 55/70
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4394 - val_loss: 2.0374
# Epoch 56/70
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4122 - val_loss: 1.8839
# Epoch 57/70
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4242 - val_loss: 2.0046
# Epoch 58/70
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4704 - val_loss: 1.7894
# Epoch 59/70
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5284 - val_loss: 1.8751
# Epoch 60/70
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4186 - val_loss: 1.8696
# Epoch 61/70
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5530 - val_loss: 1.8611
# Epoch 62/70
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4844 - val_loss: 1.8472
# Epoch 63/70
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4407 - val_loss: 1.7895
# Epoch 64/70
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5081 - val_loss: 1.8056
# Epoch 65/70
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3982 - val_loss: 1.8079
# Epoch 66/70
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4005 - val_loss: 1.7832
# Epoch 67/70
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4471 - val_loss: 1.7277
# Epoch 68/70
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5017 - val_loss: 1.8128
# Epoch 69/70
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4746 - val_loss: 1.7694
# Epoch 70/70
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4371 - val_loss: 1.7358

# %%
# Prediction

y_pred_2 = model_2.predict(X_test)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
pred_df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred_2.flatten()})
pred_df.head()
# Out:
#             Actual   Predicted
# 675111  173.660004  174.321075
# 675608  171.919998  172.634567
# 676105  172.000000  170.845978
# 676602  187.789993  179.608780
# 677099  187.029999  188.392914

# %%
# Measure the Accuracy Score

from sklearn.metrics import r2_score
 
print("Accuracy score of the predictions: {0}".format(r2_score(y_test, y_pred_2)))
Acc.append(r2_score(y_test, y_pred_2))
# Out:
# Accuracy score of the predictions: 0.9879138730390733

# %%
plt.figure(figsize=(8,8))
plt.ylabel('Close Price', fontsize=16)
plt.plot(pred_df)
plt.legend(['Actual Value', 'Predictions'])
plt.show()

# %% [markdown]
# ## CNN

# %%
X_train = np.array(X_train).reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = np.array(X_test).reshape(X_test.shape[0], X_test.shape[1], 1)

# %%
from tensorflow.keras import Sequential,utils
from tensorflow.keras.layers import Flatten, Dense, Conv1D, MaxPool1D, Dropout

def reg():
    
    model = Sequential()
    
    model.add(Conv1D(32, kernel_size=(3,), padding='same', activation='relu', input_shape = (X_train.shape[1],1)))
    model.add(Conv1D(64, kernel_size=(3,), padding='same', activation='relu'))
    model.add(Conv1D(128, kernel_size=(5,), padding='same', activation='relu'))
    
    model.add(Flatten())
    
    model.add(Dense(50, activation='relu'))
    model.add(Dense(20, activation='relu'))
    model.add(Dense(units = 1))
    
    model.compile(loss='mean_squared_error', optimizer='adam')
    
    return model

# %%
# Model Training

model_3 = reg()
model_3.fit(X_train, y_train, epochs=100, validation_split=0.2)
# Out:
# Epoch 1/100
# /home/rohit/miniconda3/envs/env/lib/python3.9/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 5888.7769 - val_loss: 7048.1084
# Epoch 2/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 592.6995 - val_loss: 10.3591
# Epoch 3/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 19.2429 - val_loss: 7.5887
# Epoch 4/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3727 - val_loss: 4.2561
# Epoch 5/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8961 - val_loss: 2.8914
# Epoch 6/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5959 - val_loss: 1.9383
# Epoch 7/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5219 - val_loss: 1.8968
# Epoch 8/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6039 - val_loss: 1.9128
# Epoch 9/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5095 - val_loss: 1.9293
# Epoch 10/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4967 - val_loss: 1.9190
# Epoch 11/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5334 - val_loss: 1.8663
# Epoch 12/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4950 - val_loss: 1.8966
# Epoch 13/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4836 - val_loss: 1.8677
# Epoch 14/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4737 - val_loss: 1.8928
# Epoch 15/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5330 - val_loss: 1.8688
# Epoch 16/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4907 - val_loss: 1.9040
# Epoch 17/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4648 - val_loss: 2.0345
# Epoch 18/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5629 - val_loss: 1.8776
# Epoch 19/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4433 - val_loss: 1.8619
# Epoch 20/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5332 - val_loss: 1.9868
# Epoch 21/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5400 - val_loss: 1.8678
# Epoch 22/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5278 - val_loss: 2.3102
# Epoch 23/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4358 - val_loss: 1.9461
# Epoch 24/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5488 - val_loss: 2.0632
# Epoch 25/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5585 - val_loss: 1.8983
# Epoch 26/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5346 - val_loss: 1.9758
# Epoch 27/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4580 - val_loss: 1.9936
# Epoch 28/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4790 - val_loss: 1.8574
# Epoch 29/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4501 - val_loss: 2.5274
# Epoch 30/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5271 - val_loss: 1.9198
# Epoch 31/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4638 - val_loss: 1.8913
# Epoch 32/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4938 - val_loss: 2.1662
# Epoch 33/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4886 - val_loss: 2.0493
# Epoch 34/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5340 - val_loss: 1.8831
# Epoch 35/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4726 - val_loss: 2.3343
# Epoch 36/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4211 - val_loss: 1.9491
# Epoch 37/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4615 - val_loss: 2.0662
# Epoch 38/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4972 - val_loss: 2.3339
# Epoch 39/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5665 - val_loss: 1.8491
# Epoch 40/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5568 - val_loss: 1.9858
# Epoch 41/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4708 - val_loss: 2.5585
# Epoch 42/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4806 - val_loss: 2.4751
# Epoch 43/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5321 - val_loss: 1.8480
# Epoch 44/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4687 - val_loss: 1.8446
# Epoch 45/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4254 - val_loss: 1.9008
# Epoch 46/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6575 - val_loss: 2.0017
# Epoch 47/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4712 - val_loss: 2.0214
# Epoch 48/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5412 - val_loss: 2.3793
# Epoch 49/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4948 - val_loss: 2.0500
# Epoch 50/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4865 - val_loss: 1.9027
# Epoch 51/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4730 - val_loss: 2.2071
# Epoch 52/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6643 - val_loss: 2.0146
# Epoch 53/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5977 - val_loss: 1.8408
# Epoch 54/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5258 - val_loss: 2.2585
# Epoch 55/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4912 - val_loss: 1.8928
# Epoch 56/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5516 - val_loss: 2.0918
# Epoch 57/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5310 - val_loss: 2.5696
# Epoch 58/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5815 - val_loss: 1.9080
# Epoch 59/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5814 - val_loss: 1.9043
# Epoch 60/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5613 - val_loss: 1.8521
# Epoch 61/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4548 - val_loss: 2.4434
# Epoch 62/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5767 - val_loss: 2.0661
# Epoch 63/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6218 - val_loss: 1.9275
# Epoch 64/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4699 - val_loss: 2.2616
# Epoch 65/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4914 - val_loss: 2.0709
# Epoch 66/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5922 - val_loss: 2.3788
# Epoch 67/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7033 - val_loss: 2.3743
# Epoch 68/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7020 - val_loss: 1.8968
# Epoch 69/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4596 - val_loss: 1.8224
# Epoch 70/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5062 - val_loss: 1.8178
# Epoch 71/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5511 - val_loss: 2.5570
# Epoch 72/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5534 - val_loss: 1.8915
# Epoch 73/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4890 - val_loss: 1.8298
# Epoch 74/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4712 - val_loss: 2.1275
# Epoch 75/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5918 - val_loss: 2.3096
# Epoch 76/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5698 - val_loss: 2.9889
# Epoch 77/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6908 - val_loss: 3.0947
# Epoch 78/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7395 - val_loss: 2.8087
# Epoch 79/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6378 - val_loss: 1.8178
# Epoch 80/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5131 - val_loss: 1.8051
# Epoch 81/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5276 - val_loss: 2.2469
# Epoch 82/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5992 - val_loss: 1.8275
# Epoch 83/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5967 - val_loss: 1.8447
# Epoch 84/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4474 - val_loss: 2.1069
# Epoch 85/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5856 - val_loss: 2.8684
# Epoch 86/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7156 - val_loss: 1.8008
# Epoch 87/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4312 - val_loss: 1.8032
# Epoch 88/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4471 - val_loss: 1.9284
# Epoch 89/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5498 - val_loss: 1.8646
# Epoch 90/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5734 - val_loss: 1.7968
# Epoch 91/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4849 - val_loss: 2.0545
# Epoch 92/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5173 - val_loss: 2.5030
# Epoch 93/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6118 - val_loss: 4.4047
# Epoch 94/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6345 - val_loss: 2.1770
# Epoch 95/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4715 - val_loss: 2.2390
# Epoch 96/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6121 - val_loss: 2.6932
# Epoch 97/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5544 - val_loss: 2.0282
# Epoch 98/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5136 - val_loss: 2.0142
# Epoch 99/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4463 - val_loss: 1.7890
# Epoch 100/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5507 - val_loss: 1.8744

# %%
# Prediction

y_pred_3 = model_3.predict(X_test)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
# Measure the Accuracy Score

from sklearn.metrics import r2_score
 
print("Accuracy score of the predictions: {0}".format(r2_score(y_test, y_pred_3)))
Acc.append(r2_score(y_test, y_pred_3))
# Out:
# Accuracy score of the predictions: 0.9865141055042455

# %%
plt.figure(figsize=(8,8))
plt.ylabel('Close Price', fontsize=16)
plt.plot(pred_df)
plt.legend(['Actual Value', 'Predictions'])
plt.show()

# %%
plt.plot(range(3), Acc, color='green', linestyle='dashed', linewidth = 3, 
         marker='o', markerfacecolor='blue', markersize=12) 
plt.ylabel('Acc')
plt.xlabel('Models')
plt.title("Accuracies")
plt.xticks(range(3), ['Linear Regression', 'ANN', 'CNN'])
plt.show()

# %% [markdown]
# ### Now converting data in a time series data and applying some more models.
